# %% [markdown]
# <a href="https://colab.research.google.com/github/cesaroliveiragoes/Statistics-for-Data-Science/blob/main/class_01_03_03_2023_Exemplos_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01

# %% [markdown]
# ##Exemplos Pandas

# %% [markdown]
# Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Listas, Dicionários e Dataframes

# %% [markdown]
# - Variável

# %%
a = 'Cesar'
a
# Out:
# 'Cesar'

# %%
b = 3
b
# Out:
# 3

# %%
c = True
c
# Out:
# True

# %% [markdown]
# - Listas

# %%
lista1 = [1, 'Cesar', 3, False]
lista1
# Out:
# [1, 'Cesar', 3, False]

# %%
lista1[1]
# Out:
# 'Cesar'

# %% [markdown]
# - Dicionário

# %%
dicionario = {'lista1': lista1, 'lista2' : [30, 20, True]}

# %%
dicionario
# Out:
# {'lista1': [1, 'Cesar', 3, False], 'lista2': [30, 20, True]}

# %%
dicionario['lista2']
# Out:
# [30, 20, True]

# %%
dicionario['lista2'][0:2]
# Out:
# [30, 20]

# %% [markdown]
# - Dataframe

# %%
dados = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
dados
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}

# %%
dados
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}

# %%
dados_df = pd.DataFrame(dados)
dados_df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# - Outra forma de carregar dataframe

# %%
dados_df = pd.DataFrame(dados, columns=['state', 'year', 'pop'])
dados_df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# Carregar Dados

# %%
dados = pd.read_csv('scouts_2015.csv')

# %%
dados
# Out:
#        atleta_id          apelido  rodada_id   ano  clube_id        clube  \
# 0          87552      Vitor Bueno         27  2015       277       Santos
# 1          87552      Vitor Bueno         28  2015       277       Santos
# 2          87552      Vitor Bueno         29  2015       277       Santos
# 3          87552      Vitor Bueno         30  2015       277       Santos
# 4          87552      Vitor Bueno         31  2015       277       Santos
# ...          ...              ...        ...   ...       ...          ...
# 29715      82943  Matheus Ribeiro         13  2015       293  Atlético-PR
# 29716      82943  Matheus Ribeiro         14  2015       293  Atlético-PR
# 29717      82943  Matheus Ribeiro         15  2015       293  Atlético-PR
# 29718      86783         Henrique          6  2015       294     Coritiba
# 29719      86783         Henrique          7  2015       294     Coritiba
#
#        posicao_id posicao  jogos_num  pontos_num  ...  FC  GC  CA  CV  SG  DD  \
# ...
